# %%
#About Spotify Tracks Attributes And Popularity dataset
import pandas as pd
df=pd.read_csv('dataset.csv')
print(df)
# Out:
#          index                track_id                 artists  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...        ...                     ...                     ...
# 113995  113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# ...

# %%
#It gives summary of a dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
#It prints first five rows
df.head()
# Out:
#    index                track_id                 artists  \
# 0      0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1      1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2      2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3      3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4      4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
#It prints last five rows
df.tail()
# Out:
#          index                track_id           artists  \
# 113995  113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996  113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997  113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998  113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999  113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
# Generate summary statistics of numeric columns ina data frame
df.describe()
# Out:
#                index     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
#Returns the dimensions of dataframe 
df.shape
# Out:
# (114000, 21)

# %%
#It prints random 2 rows
df.sample(2)
# Out:
#          index                track_id          artists    album_name  \
# 9621      9621  3xpAO0neyFYUCawAfOhMA6  Anderson Freire    Identidade
# 107608  107608  76fdtNvwn6hkOmBvgOom7L    L'Impératrice  Odyssée - EP
#
#               track_name  popularity  duration_ms  explicit  danceability  \
# 9621             Colisão          45       228066     False         0.560
# 107608  Parfum thérémine          53       304993     False         0.662
#
#         energy  ...  loudness  mode  speechiness  acousticness  \
# 9621     0.666  ...    -6.523     1       0.0321         0.448
# 107608   0.591  ...   -10.907     0       0.0330         0.454
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 9621               0.000     0.232    0.686  138.041               4
# 107608             0.878     0.105    0.204  102.045               4
#
#         track_genre
# 9621         brazil
# 107608    synth-pop
#
# [2 rows x 21 columns]

# %%
#Column names
df.columns
# Out:
# Index(['index', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
#Row index
df.index
# Out:
# RangeIndex(start=0, stop=114000, step=1)

# %%
#Select data-print single column
df['track_id']
# Out:
# 0         5SuOikwiRyPMVoIQDJUgSV
# 1         4qPNDBW1i3p13qLCt0Ki3A
# 2         1iJBSr7s7jYXzM8EGcbK5b
# 3         6lfxq3CG4xtTiEg7opyCyx
# 4         5vjLSffimiIP26QG5WcN2K
#                    ...
# 113995    2C3TZjDRiAzdyViavDJ217
# 113996    1hIz5L4IB9hN3WRYPOCGPw
# 113997    6x8ZfSoqDjuNa5SVP5QjvX
# 113998    2e6sXL2bYv4bSz6VTdnfLs
# 113999    2hETkH7cOfqmz3LqZDHZf5
# Name: track_id, Length: 114000, dtype: object

# %%
#Print multiple columns
df[['artists','album_name']]
# Out:
#                        artists  \
# 0                  Gen Hoshino
# 1                 Ben Woodward
# 2       Ingrid Michaelson;ZAYN
# 3                 Kina Grannis
# 4             Chord Overstreet
# ...                        ...
# 113995           Rainy Lullaby
# 113996           Rainy Lullaby
# 113997           Cesária Evora
# 113998        Michael W. Smith
# 113999           Cesária Evora
#
#                                                album_name
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# 4                                                 Hold On
# ...                                                   ...
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# ...

# %%
#Filter condition on particular column
df[df['popularity']<50]
# Out:
#          index                track_id           artists  \
# 23          23  0BUuuEvNa5T4lMaewyiudB        Jason Mraz
# 24          24  3Hn3LfhrQOaKihdCibJsTs        Jason Mraz
# 25          25  6D33wCKzWtNEgOovgeVJ7r        Jason Mraz
# 26          26  5IfCZDRXZrqZSm8AwE44PG        Jason Mraz
# 27          27  0dzKBptH2P5j5a0MifBMwM        Jason Mraz
# ...        ...                     ...               ...
# 113995  113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996  113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997  113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998  113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999  113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 23                                          Coffee Moment
# 24                           Human - Best Adult Pop Tunes
# 25                                       Mellow Adult Pop
# ...

# %%
#Rename column
df.rename(columns={'artists':'Singer_names'})
# Out:
#          index                track_id            Singer_names  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...        ...                     ...                     ...
# 113995  113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# ...

# %%
#Sorting data
df.sort_values(by='popularity',ascending=False)
# Out:
#        index                track_id                   artists  \
# 20001  20001  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 81051  81051  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 51664  51664  2tTmW7RDtMQtBk7m2rYeSw          Bizarrap;Quevedo
# 81210  81210  4uUG5RXrOk84mYEfFvj3cK   David Guetta;Bebe Rexha
# 89411  89411  5ww2BF9slyYgNOk37BlC4u             Manuel Turizo
# ...      ...                     ...                       ...
# 95148  95148  34olARXYeAnlabWyWtpGxe  Edgar Joel;Anthony Colon
# 95145  95145  6abSq0hivs5RJtraGRKKhS              Ray Barretto
# 68256  68256  1U6K8MHPdkqaBoJOfhXjPx                    Jhayco
# 68252  68252  5Mktfl3xR4CNPO0u5QZRal          Jhayco;Bad Bunny
# 46440  46440  3ivmnDVeJKCJjkRMNe3Dt2               The Prophet
#
#                                   album_name  \
# 20001              Unholy (feat. Kim Petras)
# 81051              Unholy (feat. Kim Petras)
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52
# ...

# %%
#sum of null values
df.isnull().sum()
# Out:
# index               0
# track_id            0
# Singer_names        1
# album_name          1
# track_name          1
# popularity          0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
#check null values
df.isnull()
# Out:
#        index  track_id  Singer_names  album_name  track_name  popularity  \
# 20001  False     False         False       False       False       False
# 81051  False     False         False       False       False       False
# 51664  False     False         False       False       False       False
# 81210  False     False         False       False       False       False
# 89411  False     False         False       False       False       False
# ...      ...       ...           ...         ...         ...         ...
# 95148  False     False         False       False       False       False
# 95145  False     False         False       False       False       False
# 68256  False     False         False       False       False       False
# 68252  False     False         False       False       False       False
# 46440  False     False         False       False       False       False
#
#        explicit  danceability  energy    key  loudness   mode  speechiness  \
# ...

# %%
#fill missing values
df.fillna(0)
# Out:
#        index                track_id              Singer_names  \
# 20001  20001  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 81051  81051  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 51664  51664  2tTmW7RDtMQtBk7m2rYeSw          Bizarrap;Quevedo
# 81210  81210  4uUG5RXrOk84mYEfFvj3cK   David Guetta;Bebe Rexha
# 89411  89411  5ww2BF9slyYgNOk37BlC4u             Manuel Turizo
# ...      ...                     ...                       ...
# 95148  95148  34olARXYeAnlabWyWtpGxe  Edgar Joel;Anthony Colon
# 95145  95145  6abSq0hivs5RJtraGRKKhS              Ray Barretto
# 68256  68256  1U6K8MHPdkqaBoJOfhXjPx                    Jhayco
# 68252  68252  5Mktfl3xR4CNPO0u5QZRal          Jhayco;Bad Bunny
# 46440  46440  3ivmnDVeJKCJjkRMNe3Dt2               The Prophet
#
#                                   album_name  \
# 20001              Unholy (feat. Kim Petras)
# 81051              Unholy (feat. Kim Petras)
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52
# ...

# %%
#drop rows with missing values
df.dropna()
# Out:
#        index                track_id              Singer_names  \
# 20001  20001  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 81051  81051  3nqQXoyQOWXiESFLlDF1hG      Sam Smith;Kim Petras
# 51664  51664  2tTmW7RDtMQtBk7m2rYeSw          Bizarrap;Quevedo
# 81210  81210  4uUG5RXrOk84mYEfFvj3cK   David Guetta;Bebe Rexha
# 89411  89411  5ww2BF9slyYgNOk37BlC4u             Manuel Turizo
# ...      ...                     ...                       ...
# 95148  95148  34olARXYeAnlabWyWtpGxe  Edgar Joel;Anthony Colon
# 95145  95145  6abSq0hivs5RJtraGRKKhS              Ray Barretto
# 68256  68256  1U6K8MHPdkqaBoJOfhXjPx                    Jhayco
# 68252  68252  5Mktfl3xR4CNPO0u5QZRal          Jhayco;Bad Bunny
# 46440  46440  3ivmnDVeJKCJjkRMNe3Dt2               The Prophet
#
#                                   album_name  \
# 20001              Unholy (feat. Kim Petras)
# 81051              Unholy (feat. Kim Petras)
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52
# ...

# %%
#read and write csv
df=pd.read_csv('dataset.csv')
df.to_csv('spotify.csv',index=False) #save to csv file

# %%
df=pd.read_csv('spotify.csv')
df
# Out:
#          index                track_id                 artists  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...        ...                     ...                     ...
# 113995  113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# ...
